# %% [markdown]
# # ***World_development_mesurement***

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/World_development_mesurement.xlsx - world_development.csv')

# %%
df
# Out:
#       Birth Rate Business Tax Rate  CO2 Emissions                   Country  \
# 0          0.020               NaN        87931.0                   Algeria
# 1          0.050               NaN         9542.0                    Angola
# 2          0.043               NaN         1617.0                     Benin
# 3          0.027               NaN         4276.0                  Botswana
# 4          0.046               NaN         1041.0              Burkina Faso
# ...          ...               ...            ...                       ...
# 2699         NaN               NaN            NaN  Turks and Caicos Islands
# 2700       0.013             46.4%            NaN             United States
# 2701       0.015             41.9%            NaN                   Uruguay
# 2702       0.020             61.9%            NaN             Venezuela, RB
# 2703       0.011               NaN            NaN     Virgin Islands (U.S.)
#
# ...

# %%
df['GDP'].value_counts()
# Out:
# $54,790,058,957     1
# $453,885,460,993    1
# $54,742,763,112     1
# $9,834,034,351      1
# $8,554,293,727      1
#                    ..
# $5,125,273,877      1
# $169,099,768,875    1
# $721,585,608,184    1
# $256,836,883,305    1
# $381,286,223,859    1
# Name: GDP, Length: 2494, dtype: int64

# %%
country1=df['Country']

# %%
country1.unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Burundi', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', "Cote d'Ivoire",
#        'Djibouti', 'Egypt, Arab Rep.', 'Equatorial Guinea', 'Eritrea',
#        'Ethiopia', 'Gabon', 'Gambia, The', 'Ghana', 'Guinea',
#        'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Swaziland',
#        'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe',
#        'Afghanistan', 'Armenia', 'Azerbaijan', 'Bangladesh', 'Bhutan',
#        'Brunei Darussalam', 'Cambodia', 'China', 'Georgia',
#        'Hong Kong SAR, China', 'India', 'Indonesia', 'Japan',
# ...

# %% [markdown]
# # **EDA**
#
# ---
#
#
#
# ---

# %%
df.isna().sum()
# Out:
# Birth Rate                 119
# Business Tax Rate         1281
# CO2 Emissions              579
# Country                      0
# Days to Start Business     986
# Ease of Business          2519
# Energy Usage               919
# GDP                        210
# Health Exp % GDP           309
# Health Exp/Capita          309
# Hours to do Tax           1288
# Infant Mortality Rate      260
# Internet Usage             173
# Lending Interest           824
# Life Expectancy Female     136
# Life Expectancy Male       136
# Mobile Phone Usage         167
# Number of Records            0
# Population 0-14            220
# Population 15-64           220
# Population 65+             220
# Population Total             0
# Population Urban            26
# Tourism Inbound            368
# Tourism Outbound           471
# dtype: int64

# %%
df1=df.drop(['Business Tax Rate','Number of Records','Ease of Business','Hours to do Tax'],axis=1,inplace=True)

# %%
df1=df.replace(to_replace=r'[$%,]', value='', regex=True)

# %%
df1["Tourism Inbound"] = df1["Tourism Inbound"].astype(float)
df1['GDP']=df1['GDP'].astype(float)
df1['Health Exp/Capita']=df1['Health Exp/Capita'].astype(float)
df1['Tourism Outbound']=df1['Tourism Outbound'].astype(float)

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
B=df1['Country']= label_encoder.fit_transform(df1['Country'])

# %%
B
# Out:
# array([  2,   5,  20, ..., 199, 202, 204])

# %%
df1.head(12)
# Out:
#     Birth Rate  CO2 Emissions  Country  Days to Start Business  Energy Usage  \
# 0        0.020        87931.0        2                     NaN       26998.0
# 1        0.050         9542.0        5                     NaN        7499.0
# 2        0.043         1617.0       20                     NaN        1983.0
# 3        0.027         4276.0       25                     NaN        1836.0
# 4        0.046         1041.0       29                     NaN           NaN
# 5        0.042          301.0       30                     NaN           NaN
# 6        0.041         3432.0       32                     NaN        6310.0
# 7        0.039          268.0       35                     NaN           NaN
# 8        0.051          176.0       36                     NaN           NaN
# 9        0.039           84.0       40                     NaN           NaN
# 10       0.048         1646.0       41                     NaN       16679.0
# ...

# %%
df1.dtypes
# Out:
# Birth Rate                float64
# CO2 Emissions             float64
# Country                     int64
# Days to Start Business    float64
# Energy Usage              float64
# GDP                       float64
# Health Exp % GDP          float64
# Health Exp/Capita         float64
# Infant Mortality Rate     float64
# Internet Usage            float64
# Lending Interest          float64
# Life Expectancy Female    float64
# Life Expectancy Male      float64
# Mobile Phone Usage        float64
# Population 0-14           float64
# Population 15-64          float64
# Population 65+            float64
# Population Total            int64
# Population Urban          float64
# Tourism Inbound           float64
# Tourism Outbound          float64
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
df2=pd.DataFrame(scale.fit_transform(df1),columns=df1.columns)

# %%
df2.head(7)
# Out:
#    Birth Rate  CO2 Emissions   Country  Days to Start Business  Energy Usage  \
# 0    0.282609       0.010610  0.009662                     NaN      0.009895
# 1    0.934783       0.001151  0.024155                     NaN      0.002746
# 2    0.782609       0.000194  0.096618                     NaN      0.000724
# 3    0.434783       0.000515  0.120773                     NaN      0.000670
# 4    0.847826       0.000125  0.140097                     NaN           NaN
# 5    0.760870       0.000035  0.144928                     NaN           NaN
# 6    0.739130       0.000413  0.154589                     NaN      0.002310
#
#         GDP  Health Exp % GDP  Health Exp/Capita  Infant Mortality Rate  \
# 0  0.003369          0.124424           0.005855               0.230216
# 1  0.000558          0.119816           0.002019               0.906475
# 2  0.000141          0.161290           0.001312               0.633094
# ...

# %% [markdown]
# # **knn**

# %%
sample=pd.read_csv('/content/World_development_mesurement.xlsx - world_development.csv')

# %%
sample1=sample.drop(['Business Tax Rate','Number of Records','Ease of Business','Hours to do Tax'],axis=1,inplace=True)

# %%
sample1=sample.replace(to_replace=r'[$%,]', value='', regex=True)

# %%
sample1["Tourism Inbound"] = sample1["Tourism Inbound"].astype(float)
sample1['GDP']=sample1['GDP'].astype(float)
sample1['Health Exp/Capita']=sample1['Health Exp/Capita'].astype(float)
sample1['Tourism Outbound']=sample1['Tourism Outbound'].astype(float)

# %%
ug1=sample1[sample1['Country']=='Uganda']
us1=sample1[sample1['Country']=='United States']
in1=sample1[sample1['Country']=='India']
fr1=sample1[sample1['Country']=='France']
ag1=sample1[sample1['Country']=='Afghanistan']
nl1=sample1[sample1['Country']== 'Netherlands']
al1=sample1[sample1['Country']== 'Algeria']

lx1=sample1[sample1['Country']== 'Luxembourg']
ch1=sample1[sample1['Country']== 'China']

# %%
ch1
# Out:
#       Birth Rate  CO2 Emissions Country  Days to Start Business  Energy Usage  \
# 60         0.014      3405180.0   China                     NaN     1161353.0
# 268        0.013      3487566.0   China                     NaN     1186797.0
# 476        0.013      3694242.0   China                     NaN     1253831.0
# 684        0.012      4525177.0   China                    48.0     1427554.0
# 892        0.012      5288166.0   China                    48.0     1639854.0
# 1100       0.012      5790017.0   China                    48.0     1775677.0
# 1308       0.012      6414463.0   China                    35.0     1938944.0
# 1516       0.012      6791805.0   China                    35.0     2044606.0
# 1724       0.012      7035444.0   China                    41.0     2120814.0
# 1932       0.012      7692211.0   China                    38.0     2286137.0
# 2140       0.012      8286892.0   China                    38.0     2516731.0
# ...

# %%
sample2=pd.concat([ug1,us1,in1,ch1,lx1,al1],axis=0)

# %%
sample2
# Out:
#       Birth Rate  CO2 Emissions  Country  Days to Start Business  \
# 50         0.048         1533.0   Uganda                     NaN
# 258        0.048         1621.0   Uganda                     NaN
# 466        0.048         1668.0   Uganda                     NaN
# 674        0.047         1709.0   Uganda                    34.0
# 882        0.047         1852.0   Uganda                    34.0
# ...          ...            ...      ...                     ...
# 1664       0.024       114619.0  Algeria                    25.0
# 1872       0.024       124586.0  Algeria                    25.0
# 2080       0.025       123475.0  Algeria                    25.0
# 2288       0.025            NaN  Algeria                    25.0
# 2496       0.025            NaN  Algeria                    25.0
#
#       Energy Usage           GDP  Health Exp % GDP  Health Exp/Capita  \
# 50             NaN  6.193247e+09             0.066               16.0
# ...

# %%
sample2['Country']= label_encoder.fit_transform(sample2['Country'])

# %%
sample2.head(20)
# Out:
#       Birth Rate  CO2 Emissions  Country  Days to Start Business  \
# 50         0.048         1533.0        4                     NaN
# 258        0.048         1621.0        4                     NaN
# 466        0.048         1668.0        4                     NaN
# 674        0.047         1709.0        4                    34.0
# 882        0.047         1852.0        4                    34.0
# 1090       0.047         2285.0        4                    34.0
# 1298       0.046         2655.0        4                    28.0
# 1506       0.046         3128.0        4                    28.0
# 1714       0.046         3161.0        4                    25.0
# 1922       0.045         3366.0        4                    25.0
# 2130       0.045         3784.0        4                    24.0
# 2338       0.044            NaN        4                    33.0
# 2546       0.044            NaN        4                    33.0
# ...

# %%
sample3=pd.DataFrame(scale.fit_transform(sample2),columns=sample2.columns)

# %%
sample3.head(3)
# Out:
#    Birth Rate  CO2 Emissions  Country  Days to Start Business  Energy Usage  \
# 0         1.0       0.000000      0.8                     NaN           NaN
# 1         1.0       0.000011      0.8                     NaN           NaN
# 2         1.0       0.000016      0.8                     NaN           NaN
#
#         GDP  Health Exp % GDP  Health Exp/Capita  Infant Mortality Rate  \
# 0  0.000022          0.236486           0.000000               1.000000
# 1  0.000000          0.277027           0.000113               0.954023
# 2  0.000021          0.297297           0.000225               0.908046
#
#    Internet Usage  ...  Life Expectancy Female  Life Expectancy Male  \
# 0             0.0  ...                0.000000              0.000000
# 1             0.0  ...                0.027778              0.032258
# 2             0.0  ...                0.055556              0.064516
#
#    Mobile Phone Usage  Population 0-14  Population 15-64  Population 65+  \
# ...

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer(max_iter=10, random_state=0)
A=imp.fit(sample3)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/impute/_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
A
# Out:
# IterativeImputer(random_state=0)

# %%
df3=pd.DataFrame(A.transform(df2),columns=df2.columns)

# %%
df3['Country']=country1

# %%
df3.isna().sum()
# Out:
# Birth Rate                0
# CO2 Emissions             0
# Country                   0
# Days to Start Business    0
# Energy Usage              0
# GDP                       0
# Health Exp % GDP          0
# Health Exp/Capita         0
# Infant Mortality Rate     0
# Internet Usage            0
# Lending Interest          0
# Life Expectancy Female    0
# Life Expectancy Male      0
# Mobile Phone Usage        0
# Population 0-14           0
# Population 15-64          0
# Population 65+            0
# Population Total          0
# Population Urban          0
# Tourism Inbound           0
# Tourism Outbound          0
# dtype: int64

# %%
min_value = df3['GDP'].min()
max_value = df3['GDP'].max()

# %%
bins = np.linspace(min_value,max_value,4)
bins
labels = ['low', 'medium', 'high']

# %%
df['bins'] = pd.cut(df3['GDP'], bins=bins, labels=labels, include_lowest=True)

# %%
df['bins']
# Out:
# 0       medium
# 1       medium
# 2       medium
# 3       medium
# 4       medium
#          ...
# 2699      high
# 2700      high
# 2701    medium
# 2702    medium
# 2703    medium
# Name: bins, Length: 2704, dtype: category
# Categories (3, object): ['low' < 'medium' < 'high']

# %%
df3['gdp']=df['bins']

# %%
df3.head(10)
# Out:
#    Birth Rate  CO2 Emissions                   Country  \
# 0    0.282609       0.010610                   Algeria
# 1    0.934783       0.001151                    Angola
# 2    0.782609       0.000194                     Benin
# 3    0.434783       0.000515                  Botswana
# 4    0.847826       0.000125              Burkina Faso
# 5    0.760870       0.000035                   Burundi
# 6    0.739130       0.000413                  Cameroon
# 7    0.695652       0.000031  Central African Republic
# 8    0.956522       0.000020                      Chad
# 9    0.695652       0.000009                   Comoros
#
#    Days to Start Business  Energy Usage       GDP  Health Exp % GDP  \
# 0                0.325181      0.009895  0.003369          0.124424
# 1                0.394439      0.002746  0.000558          0.119816
# 2                0.355326      0.000724  0.000141          0.161290
# 3                0.323916      0.000670  0.000352          0.179724
# ...

# %%
df3['gdp'].value_counts()
# Out:
# medium    2645
# high        39
# low         20
# Name: gdp, dtype: int64

# %%
df3[df3['Country']=='India']
# Out:
#       Birth Rate  CO2 Emissions Country  Days to Start Business  Energy Usage  \
# 63      0.413043       0.143197   India                0.494131      0.167609
# 271     0.391304       0.145270   India                0.493714      0.170286
# 479     0.391304       0.148039   India                0.494877      0.175066
# 687     0.369565       0.154691   India                0.126984      0.179454
# 895     0.369565       0.162729   India                0.126984      0.190326
# 1103    0.347826       0.170284   India                0.101010      0.197740
# 1311    0.347826       0.181535   India                0.049062      0.207930
# 1519    0.326087       0.194451   India                0.046176      0.221669
# 1727    0.326087       0.218572   India                0.041847      0.232043
# 1935    0.326087       0.239204   India                0.041847      0.256020
# 2143    0.304348       0.242409   India                0.040404      0.265326
# ...

# %% [markdown]
# # **visualization**
#
# ---
#
#
#
# ---

# %%
correlation=df3.corr()

# %%
correlation
# Out:
#                         Birth Rate  CO2 Emissions  Days to Start Business  \
# Birth Rate                1.000000      -0.165223                0.056397
# CO2 Emissions            -0.165223       1.000000                0.020819
# Days to Start Business    0.056397       0.020819                1.000000
# Energy Usage              0.069453       0.596970               -0.021591
# GDP                      -0.153310       0.431492               -0.094495
# Health Exp % GDP         -0.137417       0.063191               -0.186210
# Health Exp/Capita        -0.480767       0.169013               -0.069322
# Infant Mortality Rate     0.825711      -0.107142                0.205767
# Internet Usage           -0.617785       0.142350               -0.286336
# Lending Interest          0.316673      -0.049100                0.096215
# Life Expectancy Female   -0.864031       0.099162               -0.134851
# Life Expectancy Male     -0.823184       0.122978               -0.137239
# ...

# %%
plt.figure(figsize=(20,20))
sns.clustermap(correlation,annot=True, linewidth=.5)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(df3['gdp'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data=df3,x=df3['CO2 Emissions'],y=df3['Population Total'],hue=df3['gdp'],height=9)
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.scatterplot(data=df3,x=df3['Days to Start Business'],y=df3['Lending Interest'],hue=df3['gdp'])
sns.rugplot(data=df3,x=df3['Days to Start Business'],y=df3['Lending Interest'])
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.relplot(data=df3,x=df3['Infant Mortality Rate'],y=df3['Birth Rate'],hue=df3['gdp'])

# %%
plt.figure(figsize=(18,12))
plt.subplot(1,2,1)
sns.lineplot(data=df3,x=df3['gdp'],y=df3['Tourism Inbound'])
plt.subplot(1,2,2)
sns.lineplot(data=df3,x=df3['gdp'],y=df3['Tourism Outbound'])

# %%
sns.displot(data=df3,y=df3['Birth Rate'],x=df3['Population 0-14'])

# %% [markdown]
# # **Factor Analysis**

# %%
# !pip install factor_analyzer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 676 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 199 kB 66.0 MB/s
# ...
#      |████████████████████████████████| 98 kB 9.6 MB/s
# ...
#      |████████████████████████████████| 8.8 MB 71.4 MB/s
# ...
#      |████████████████████████████████| 468 kB 78.9 MB/s
# ...
#   Created wheel for factor-analyzer: filename=factor_analyzer-0.4.1-py2.py3-none-any.whl size=42034 sha256=c0b314c63e4cb167c2beb9f0071b6d5da70ed086e999ae16835e00f67dd74eb6
#   Stored in directory: /root/.cache/pip/wheels/f5/8f/2e/a689c21bc4bf04f84ceebf4b1f5846cacc04bfe179e7ad5ab0
# Successfully built factor-analyzer
# ...

# %%
from factor_analyzer import FactorAnalyzer

# %%
df3['Country']= label_encoder.fit_transform(df3['Country'])

# %%
df3['gdp']= label_encoder.fit_transform(df3['gdp'])

# %%
df3
# Out:
#       Birth Rate  CO2 Emissions  Country  Days to Start Business  \
# 0       0.282609       0.010610        2                0.325181
# 1       0.934783       0.001151        5                0.394439
# 2       0.782609       0.000194       20                0.355326
# 3       0.434783       0.000515       25                0.323916
# 4       0.847826       0.000125       29                0.369901
# ...          ...            ...      ...                     ...
# 2699    0.264939       0.080096      193                0.141058
# 2700    0.130435       0.560207      198                0.005772
# 2701    0.173913       0.024995      199                0.008658
# 2702    0.282609       0.029237      202                0.206349
# 2703    0.086957      -0.019011      204                0.154168
#
#       Energy Usage       GDP  Health Exp % GDP  Health Exp/Capita  \
# 0         0.009895  0.003369          0.124424           0.005855
# ...

# %%
x=df3[df3.columns]

# %%
fa=FactorAnalyzer()

# %%
fa.fit(x)
# Out:
# FactorAnalyzer(rotation_kwargs={})

# %%
ev, v = fa.get_eigenvalues()
ev
plt.plot(range(1,x.shape[1]+1),ev)

# %%
fa = FactorAnalyzer(7, rotation='varimax')
fa.fit(x)
loads = fa.loadings_
print(loads)
# Out:
# [[-9.43709263e-01 -5.31110864e-02 -5.93885606e-02  4.42072271e-02
#   -1.67643993e-01  4.63779237e-02  9.94534094e-02]
#  [ 1.12758436e-01  2.79470743e-01  8.35369979e-01 -7.59885796e-02
#    1.79005629e-02  8.51637493e-02 -8.62555447e-02]
#  [-3.68685361e-02  2.88249526e-02 -3.33460332e-02 -6.99643179e-04
#    1.70461960e-02  3.00400405e-02  4.23740038e-01]
#  [-6.56202759e-02 -9.93424590e-02  2.58394451e-02 -6.17475729e-01
#   -3.23190633e-02  7.68419912e-02 -2.71415904e-02]
#  [-7.39648156e-02  1.89295755e-01  7.02492669e-01  7.93410857e-02
#    3.56197977e-02  5.13193208e-02  4.79129337e-01]
#  [ 8.26018324e-02  9.39433424e-01  2.01073792e-01 -1.08185673e-02
#    1.30290509e-02  5.49021167e-02  4.59837623e-02]
#  [ 1.04298631e-01  4.57816800e-01 -8.55305812e-02  1.17420517e-01
#    4.55275846e-01  1.47620027e-02  2.89119988e-01]
#  [ 4.83417886e-01  4.15993256e-01 -5.11400658e-02  6.86489538e-02
#    2.73530646e-01  5.41875396e-01  7.65893351e-02]
# ...

# %%
new_variables = fa.fit_transform(x)

# %%
new_variables
# Out:
# array([[ 0.10701408, -0.05982799, -0.10800195, ..., -0.91626544,
#         -0.69476727, -0.69040957],
#        [-2.37329858,  0.03636468, -0.18026773, ...,  0.67303738,
#          1.28624014, -1.48843863],
#        [-1.55913136,  0.05052446, -0.36099305, ..., -0.20299839,
#          0.69723155, -0.63525562],
#        ...,
#        [ 0.67669164, -0.3625355 ,  0.08219861, ...,  0.90377981,
#          0.28562116,  0.49477545],
#        [ 0.48603861, -0.29087758,  0.43641696, ..., -0.87898231,
#          0.67813582,  0.79735582],
#        [ 0.76275443,  4.25427887, -1.34026918, ...,  1.54237293,
#         -0.08075038,  1.67961275]])

# %%
a=pd.concat([pd.DataFrame(new_variables[:,0:7],columns=['factor1','factor2','factor3','factor4','factor5','factor6','factor7'])],axis=1)

# %%
a
# Out:
#        factor1   factor2   factor3   factor4   factor5   factor6   factor7
# 0     0.107014 -0.059828 -0.108002 -1.222794 -0.916265 -0.694767 -0.690410
# 1    -2.373299  0.036365 -0.180268 -0.737650  0.673037  1.286240 -1.488439
# 2    -1.559131  0.050524 -0.360993 -0.695482 -0.202998  0.697232 -0.635256
# 3    -1.097474 -0.161932 -0.096120 -0.702853  0.259293 -0.284225 -0.981502
# 4    -1.925154 -0.036923 -0.105194 -0.490521  0.252379  0.722490 -0.372791
# ...        ...       ...       ...       ...       ...       ...       ...
# 2699 -0.199361  4.570023 -0.681067 -1.044896  0.175227  1.873884  1.434810
# 2700  0.135979  9.718568  3.159209  0.609156  0.652733  0.037102  2.181690
# 2701  0.676692 -0.362535  0.082199  1.016854  0.903780  0.285621  0.494775
# 2702  0.486039 -0.290878  0.436417  0.704517 -0.878982  0.678136  0.797356
# 2703  0.762754  4.254279 -1.340269 -1.077062  1.542373 -0.080750  1.679613
#
# [2704 rows x 7 columns]

# %%
fig=plt.figure(figsize=(12,12))
sns.scatterplot(data=a)

# %% [markdown]
# # **Hierarchical**

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
plt.figure(figsize=(20,20))
dg=sch.dendrogram(sch.linkage(a,method='ward'))

# %%
hclusters=AgglomerativeClustering(n_clusters=4,affinity='euclidean',linkage='ward')

# %%
y=pd.DataFrame(hclusters.fit_predict(a),columns=['clustersid'])
y['clustersid']
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 2699    1
# 2700    1
# 2701    2
# 2702    0
# 2703    1
# Name: clustersid, Length: 2704, dtype: int64

# %%
y['clustersid'].value_counts()
# Out:
# 0    1504
# 2     582
# 3     567
# 1      51
# Name: clustersid, dtype: int64

# %%
clustersid=y['clustersid']

# %%
df3['clustersid']=clustersid

# %%
df3['Country']=country1

# %%
df3
# Out:
#       Birth Rate  CO2 Emissions                   Country  \
# 0       0.282609       0.010610                   Algeria
# 1       0.934783       0.001151                    Angola
# 2       0.782609       0.000194                     Benin
# 3       0.434783       0.000515                  Botswana
# 4       0.847826       0.000125              Burkina Faso
# ...          ...            ...                       ...
# 2699    0.264939       0.080096  Turks and Caicos Islands
# 2700    0.130435       0.560207             United States
# 2701    0.173913       0.024995                   Uruguay
# 2702    0.282609       0.029237             Venezuela, RB
# 2703    0.086957      -0.019011     Virgin Islands (U.S.)
#
#       Days to Start Business  Energy Usage       GDP  Health Exp % GDP  \
# 0                   0.325181      0.009895  0.003369          0.124424
# 1                   0.394439      0.002746  0.000558          0.119816
# ...

# %%
#developed Nations
df3[df3['clustersid']==2].head(7)
# Out:
#     Birth Rate  CO2 Emissions               Country  Days to Start Business  \
# 62    0.021739       0.004882  Hong Kong SAR, China                0.250515
# 65    0.043478       0.147170                 Japan                0.253798
# 71    0.043478       0.000196      Macao SAR, China                0.283369
# 89    0.065217       0.007686               Austria                0.287531
# 91    0.086957       0.013962               Belgium                0.280958
# 95    0.130435       0.000826                Cyprus                0.300372
# 96    0.043478       0.015041        Czech Republic                0.296886
#
#     Energy Usage       GDP  Health Exp % GDP  Health Exp/Capita  \
# 62      0.004907  0.010564          0.257940           0.314483
# 65      0.190253  0.291245          0.313364           0.285887
# 71      0.031089  0.000372          0.376116           0.316136
# 89      0.010467  0.011820          0.423963           0.242378
# ...

# %%
#emerging Nation
df3[df3['clustersid']==0].head(7)
# Out:
#     Birth Rate  CO2 Emissions                Country  Days to Start Business  \
# 0     0.282609       0.010610                Algeria                0.325181
# 14    0.391304       0.017053       Egypt, Arab Rep.                0.331830
# 26    0.326087       0.005685                  Libya                0.282584
# 27    0.739130       0.000225             Madagascar                0.331231
# 31    0.217391       0.000333              Mauritius                0.291264
# 32    0.326087       0.004091                Morocco                0.309804
# 38    0.630435       0.000005  Sao Tome and Principe                0.269869
#
#     Energy Usage           GDP  Health Exp % GDP  Health Exp/Capita  \
# 0       0.009895  3.368945e-03          0.124424           0.005855
# 14      0.014903  6.142092e-03          0.211982           0.007773
# 26      0.005826  2.082762e-03          0.119816           0.025237
# 27      0.221189  2.348219e-04          0.193548           0.001009
# ...

# %%
#underdevleoped Nations
df3[df3['clustersid']==1].head(7)
# Out:
#      Birth Rate  CO2 Emissions        Country  Days to Start Business  \
# 42     0.913043       0.000062        Somalia                0.252833
# 152    0.326087       0.097667           Guam                0.117159
# 204    0.152174       0.689469  United States                0.104166
# 250    0.891304       0.000060        Somalia                0.253044
# 360    0.304348       0.109175           Guam                0.123305
# 412    0.152174       0.675935  United States                0.111011
# 458    0.891304       0.000068        Somalia                0.250449
#
#      Energy Usage       GDP  Health Exp % GDP  Health Exp/Capita  \
# 42       0.249230  0.257620          0.570773           0.083477
# 152      0.243102  0.583397          0.637946           0.261340
# 204      0.833415  0.633421          0.589862           0.483343
# 250      0.249285  0.257526          0.582864           0.112059
# 360      0.242436  0.584814          0.618583           0.325994
# ...

# %%
#backward Nations
df3[df3['clustersid']==3].head(7)
# Out:
#    Birth Rate  CO2 Emissions                   Country  \
# 1    0.934783       0.001151                    Angola
# 2    0.782609       0.000194                     Benin
# 3    0.434783       0.000515                  Botswana
# 4    0.847826       0.000125              Burkina Faso
# 5    0.760870       0.000035                   Burundi
# 6    0.739130       0.000413                  Cameroon
# 7    0.695652       0.000031  Central African Republic
#
#    Days to Start Business  Energy Usage       GDP  Health Exp % GDP  \
# 1                0.394439      0.002746  0.000558          0.119816
# 2                0.355326      0.000724  0.000141          0.161290
# 3                0.323916      0.000670  0.000352          0.179724
# 4                0.369901      0.060539  0.000157          0.198157
# 5                0.377418      0.095601  0.000050          0.253456
# 6                0.359539      0.002310  0.000568          0.165899
# ...

# %%
fig=plt.figure(figsize=(12,12))
sns.scatterplot(x=df3['Life Expectancy Female'],y=df3['Life Expectancy Male'],data=df3,hue=clustersid)

# %%
fig=plt.figure(figsize=(12,12))
sns.scatterplot(data=df3, x=df3['Days to Start Business'],y=df3['Birth Rate'],hue=clustersid)
